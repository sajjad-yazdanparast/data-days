# %%
import pandas as pd 
import numpy as np 
from time import time

# %%
raw_ad_image = pd.read_pickle('/media/sajjad/New Volume/Dataset/datadays2020_contest_public_dataset/raw_ad_image3')

# %%
train_plus_test = pd.read_pickle('/media/sajjad/New Volume/Dataset/datadays2020_contest_public_dataset/train_plus_test.pkl')

# %%
event = pd.read_csv('/media/sajjad/New Volume/Dataset/datadays2020_contest_public_dataset/event.csv')

# %%
click_train = pd.read_csv('/media/sajjad/New Volume/Dataset/datadays2020_contest_public_dataset/click_train.csv')

# %%
pre_user_ctr = event[['displayId','userId']].merge(train_plus_test.drop('adId',axis=1))

# %%
# stime = time()
# user_ids = pre_user_ctr['userId'].unique()
# user_ctrs = []
# i = 0
# for id_ in user_ids :
#     if i%1000 == 0 :
#         print (i)
#     grabed = pre_user_ctr[pre_user_ctr['userId']==id_]
#     click_serie = grabed['clicked']
#     click_df = grabed[['clicked']]
#     sum_ = np.sum(click_serie)
#     makh = len(click_serie) - len(click_df[click_serie.isnull()])
#     user_ctrs.append(sum_/makh)
#     i+=1
# ftime = time()
# print((ftime-stime)/60)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# ...

# %%
# user_ctr = pd.DataFrame.from_dict({
#     'userId' : user_ids ,
#     'ctr' : user_ctrs
# })

# %%
# user_ctr.to_pickle('/media/sajjad/New Volume/Dataset/datadays2020_contest_public_dataset/raw_user_ctr.pkl')

# %%
# user_ctr.index = user_ctr['userId']
# user_ctr.loc[user_ctr[user_ctr['ctr'].isnull()].index,'ctr'] =  0.21590900000000002
# Out:
#           userId       ctr
# userId
# 2688642  2688642  0.333333
# 2688641  2688641  0.200000
# 2688638  2688638  0.333333
# 1962852  1962852  0.250000
# 2687719  2687719  0.250000
# ...          ...       ...
# 55            55       NaN
# 48            48       NaN
# 44            44       NaN
# 30            30       NaN
# 22            22       NaN
#
# [844374 rows x 2 columns]

# %%
# user_ctr.to_pickle('/media/sajjad/New Volume/Dataset/datadays2020_contest_public_dataset/user_ctr.pkl')

# %%
train_plus_test
# Out:
#          displayId  adId  clicked
# 0          1210227  7182      0.0
# 1          1210227  7125      0.0
# 2          1210227  7181      0.0
# 3          1210227   535      0.0
# 4          1210227  7174      1.0
# ...            ...   ...      ...
# 4841287    1328957  7039      NaN
# 4841288    1328976  7167      NaN
# 4841289    1328976   535      NaN
# 4841290    1328976  7174      NaN
# 4841291    1328976  7182      NaN
#
# [4841292 rows x 3 columns]

# %%
pre_avg = event[['displayId','userId']].merge(train_plus_test).drop('displayId',axis=1)

# %%
pre_avg
# Out:
#           userId  adId  clicked
# 0        2688642     6      1.0
# 1        2688642    15      0.0
# 2        2688642  3610      0.0
# 3        2688641  5279      0.0
# 4        2688641  5271      0.0
# ...          ...   ...      ...
# 4841287       22  3614      NaN
# 4841288       22  6703      NaN
# 4841289       22  6423      NaN
# 4841290       22  6988      NaN
# 4841291       22  5922      NaN
#
# [4841292 rows x 3 columns]

# %%
pre_avg[pre_avg['adId']==7863]  # karbarani k 7863 ra dide and
# Out:
#          userId  adId  clicked
# 4836053    5067  7863      NaN
# 4840619     685  7863      NaN

# %%
user_ctr.loc[pre_avg[pre_avg['adId']==7863]['userId'].values]  # ctr karbarani ist k 7863 ra dide and
# Out:
#         userId       ctr
# userId
# 5067      5067  0.215909
# 685        685  0.215909

# %%
user_ctr.loc[pre_avg[(pre_avg['adId']==7863)&(pre_avg['clicked']==0)]['userId'].values]
# ['userId'].values
# Out:
# Empty DataFrame
# Columns: [userId, ctr]
# Index: []

# %%
np.mean(user_ctr.loc[pre_avg[(pre_avg['adId']==7863)]['userId'].values]['ctr'])
# Out:
# 0.21590900000000002

# %%
stime = time()
ad_ids = pre_avg['adId'].unique()
averages = []
i = 0 
for id_ in ad_ids :
    if i%50 == 0 :
        print(i)
    avg = np.mean(user_ctr.loc[pre_avg[pre_avg['adId']==id_]['userId'].values]['ctr'])
    averages.append(avg)
    i+=1
    
ftime = time()
print((ftime-stime)/60)
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
# 3050
# 3100
# 3150
# 3200
# 3250
# 1.6360102772712708

# %%
ad_user_clicked_average_ctr = pd.DataFrame.from_dict({
    'adId' : ad_ids ,
    'avg' : averages
})
ad_user_clicked_average_ctr.head()
# Out:
#    adId       avg
# 0     6  0.274578
# 1    15  0.267970
# 2  3610  0.188139
# 3  5279  0.187621
# 4  5271  0.202253

# %%
ad_user_clicked_average_ctr.to_pickle('/media/sajjad/New Volume/Dataset/datadays2020_contest_public_dataset/ad_user_clicked_average_ctr.pkl')
